# %% [markdown]
# #Modulo panda
# ![image](https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExejY4OGgya3hpcnljZGZ3a2hqOHRkbG90NW5menJzem4wbXQ1em1zMCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/EPcvhM28ER9XW/giphy.gif)

# %%
import pandas as pd

mobiles = pd.read_csv("Mobiles.csv", encoding='unicode_escape')

mobiles
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %%
mobiles.columns
# Out:
# Index(['Company Name', 'Model Name', 'Mobile Weight', 'RAM', 'Front Camera',
#        'Back Camera', 'Processor', 'Battery Capacity', 'Screen Size',
#        'Launched Price (Pakistan)', 'Launched Price (India)',
#        'Launched Price (China)', 'Launched Price (USA)',
#        'Launched Price (Dubai)', 'Launched Year'],
#       dtype='object')

# %%
mobiles_2 =mobiles[['Model Name','Front Camera',
       'Back Camera', 'Processor', 'Battery Capacity', 'Screen Size',
       'Launched Price (Pakistan)', 'Launched Price (India)']]
mobiles_2
# Out:
#                Model Name     Front Camera Back Camera            Processor  \
# 0         iPhone 16 128GB             12MP        48MP           A17 Bionic
# 1         iPhone 16 256GB             12MP        48MP           A17 Bionic
# 2         iPhone 16 512GB             12MP        48MP           A17 Bionic
# 3    iPhone 16 Plus 128GB             12MP        48MP           A17 Bionic
# 4    iPhone 16 Plus 256GB             12MP        48MP           A17 Bionic
# ..                    ...              ...         ...                  ...
# 925          Pad 5G 128GB              8MP         8MP  Snapdragon 7s Gen 2
# 926          Pad 5G 256GB              8MP         8MP  Snapdragon 7s Gen 2
# 927  Galaxy Z Fold6 256GB  10MP, 4MP (UDC)        50MP   Snapdragon 8 Gen 3
# 928  Galaxy Z Fold6 512GB  10MP, 4MP (UDC)        50MP   Snapdragon 8 Gen 3
# 929    Galaxy Z Fold6 1TB  10MP, 4MP (UDC)        50MP   Snapdragon 8 Gen 3
#
# ...

# %%
#los  primeros 10
mobiles_2.head(10)
# Out:
#                 Model Name Front Camera  Back Camera   Processor  \
# 0          iPhone 16 128GB         12MP         48MP  A17 Bionic
# 1          iPhone 16 256GB         12MP         48MP  A17 Bionic
# 2          iPhone 16 512GB         12MP         48MP  A17 Bionic
# 3     iPhone 16 Plus 128GB         12MP         48MP  A17 Bionic
# 4     iPhone 16 Plus 256GB         12MP         48MP  A17 Bionic
# 5     iPhone 16 Plus 512GB         12MP         48MP  A17 Bionic
# 6      iPhone 16 Pro 128GB    12MP / 4K  50MP + 12MP     A17 Pro
# 7      iPhone 16 Pro 256GB    12MP / 4K  50MP + 12MP     A17 Pro
# 8      iPhone 16 Pro 512GB    12MP / 4K  50MP + 12MP     A17 Pro
# 9  iPhone 16 Pro Max 128GB    12MP / 4K  48MP + 12MP     A17 Pro
#
#   Battery Capacity Screen Size Launched Price (Pakistan)  \
# 0         3,600mAh  6.1 inches               PKR 224,999
# 1         3,600mAh  6.1 inches               PKR 234,999
# 2         3,600mAh  6.1 inches               PKR 244,999
# ...

# %%
# Muestra los datos de iphond 16 Pro Max 128GB
mobiles_2.T[9]
# Out:
# Model Name                   iPhone 16 Pro Max 128GB
# Front Camera                               12MP / 4K
# Back Camera                              48MP + 12MP
# Processor                                    A17 Pro
# Battery Capacity                            4,500mAh
# Screen Size                               6.7 inches
# Launched Price (Pakistan)                PKR 314,999
# Launched Price (India)                   INR 109,999
# Name: 9, dtype: object

# %%
m = mobiles_2.iloc[8].T

# %%
m
# Out:
# Model Name                   iPhone 16 Pro 512GB
# Front Camera                           12MP / 4K
# Back Camera                          50MP + 12MP
# Processor                                A17 Pro
# Battery Capacity                        4,400mAh
# Screen Size                           6.1 inches
# Launched Price (Pakistan)            PKR 314,999
# Launched Price (India)               INR 114,999
# Name: 8, dtype: object
